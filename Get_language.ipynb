# %%
import pandas as pd
# from google.cloud import translate_v2 as translate
pd.options.display.max_columns = None
pd.options.display.max_rows = None

# %%
df = pd.read_csv("foods_lang.csv", low_memory=False)

# %%
translate_client = translate.Client.from_service_account_json("key.json")

# %%
lang = [translate_client.detect_language(x)["language"] for x in list(df.ingredients_text)]

# %%
df["lang"] = lang

# %%
df.to_csv("foods_lang.csv", index=False)

# %%
from collections import Counter
Counter(df.lang)
# Out:
# Counter({'fr': 154387,
#          'en': 249372,
#          'de': 27165,
#          'ht': 11,
#          'nl': 2063,
#          'es': 17800,
#          'it': 5386,
#          'gl': 278,
#          'pt': 1258,
#          'sv': 2051,
#          'tr': 242,
#          'gu': 14,
#          'so': 34,
#          'ca': 460,
#          'hi': 37,
#          'mi': 31,
#          'vi': 33,
#          'jw': 27,
#          'ro': 1038,
#          'ja': 78,
#          'zh-TW': 40,
#          'ar': 105,
#          'co': 835,
#          'eu': 15,
#          'hu': 492,
#          'bg': 65,
#          'lb': 323,
#          'zh-CN': 26,
#          'lv': 154,
#          'ny': 12,
#          'la': 81,
#          'lt': 29,
#          'hr': 236,
#          'bn': 5,
#          'pl': 2587,
#          'ga': 2,
#          'cs': 458,
#          'tl': 11,
#          'da': 279,
#          'gd': 38,
#          'no': 335,
#          'mr': 8,
#          'ta': 4,
#          'kn': 9,
#          'id': 53,
# ...

# %%
df[:10]
# Out:
#             code                                                url  \
# 0  0000000000100  http://world-en.openfoodfacts.org/product/0000...
# 1  0000000005470  http://world-en.openfoodfacts.org/product/0000...
# 2  0000000043595  http://world-en.openfoodfacts.org/product/0000...
# 3  0000000274722  http://world-en.openfoodfacts.org/product/0000...
# 4  0000000290616  http://world-en.openfoodfacts.org/product/0000...
# 5  0000000491228  http://world-en.openfoodfacts.org/product/0000...
# 6  0000001938067  http://world-en.openfoodfacts.org/product/0000...
# 7       00000024  http://world-en.openfoodfacts.org/product/0000...
# 8  0000004302544  http://world-en.openfoodfacts.org/product/0000...
# 9     0000005016  http://world-en.openfoodfacts.org/product/0000...
#
#            creator   created_t      created_datetime  last_modified_t  \
# 0            del51  1444572561  2015-10-11T14:09:21Z       1444659212
# 1          kiliweb  1511778860  2017-11-27T10:34:20Z       1550180518
# ...
